# %%
# !pip install kitsune
# Out:
# Collecting kitsune
#   Downloading kitsune-1.3.3-py2.py3-none-any.whl (32 kB)
# Requirement already satisfied: numpy>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from kitsune) (1.23.5)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.10/dist-packages (from kitsune) (1.11.3)
# Requirement already satisfied: tqdm>=4.32 in /usr/local/lib/python3.10/dist-packages (from kitsune) (4.66.1)
# Installing collected packages: kitsune
# Successfully installed kitsune-1.3.3

# %%
with open('dhcp.log', 'r') as infile, open('output.csv', 'w') as outfile:
    stripped_lines = (line.strip() for line in infile)
    lines = (line.split(':') for line in stripped_lines if line)
    writer = csv.writer(outfile)
    writer.writerows(lines)

# %%
import kitsune
# Import other necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("/content/project/output.csv")

# %%
df.head()
# Out:
#   1331901047.230000\tCCHNFI4C6RAO93bP7\t192.168.202.76\t68\t192.168.202.1\t67\t00  \
# 0  1331901117.740000\tCouYOF1J4EnQkQNSl3\t192.168...
# 1  1331901120.620000\tC9svD93TrEvPshF7Gf\t192.168...
# 2  1331901121.800000\tC2nAD54rXz5nILppHh\t192.168...
# 3  1331901182.540000\tCVRJN6491gIrhKWzHk\t192.168...
# 4  1331901216.820000\tCl244gl1V2Yyf4h1f\t192.168....
#
#    26  9e  83  a2  30\t192.168.202.76\t0.000000\t2767872470
# 0  26  b9  da  95  2c\t192.168.204.69\t0.000000\t2023309577
# 1  de  f1  2e  6a    5a\t192.168.202.102\t0.000000\t7111068
# 2  26  9e  83  a2  30\t192.168.202.76\t0.000000\t4022009768
# 3  26  b9  da  95  2c\t192.168.204.69\t0.000000\t3428947570
# 4  26  9e  83  a2  30\t192.168.202.76\t0.000000\t3106841135

# %%
#DataFrame with columns
columns = pd.DataFrame(list(df.columns.values[1:]))

#DataFrame with data types
data_types = pd.DataFrame(df.dtypes, columns=['Data Type'])

#DataFrame with Count
data_count = pd.DataFrame(df.count(), columns=['Count'])

#DataFrame with unique values
unique_value_counts = pd.DataFrame(columns=['Unique Values'])
for v in list(df.columns.values):
    unique_value_counts.loc[v] = [df[v].nunique()]

missing_data_counts = pd.DataFrame(df.isnull().sum(), columns=['Missing Values'])
data_quality_report = data_types.join(data_count).join(unique_value_counts).join(missing_data_counts)
print('Data Quality Report')
data_quality_report
# Out:
# Data Quality Report
#                                                    Data Type  Count  \
# 1331901047.230000\tCCHNFI4C6RAO93bP7\t192.168.2...    object   1501
# 26                                                    object   1501
# 9e                                                    object   1501
# 83                                                    object   1501
# a2                                                    object   1501
# 30\t192.168.202.76\t0.000000\t2767872470              object   1501
#
#                                                     Unique Values  \
# 1331901047.230000\tCCHNFI4C6RAO93bP7\t192.168.2...           1500
# 26                                                             33
# 9e                                                             37
# 83                                                             68
# a2                                                             68
# 30\t192.168.202.76\t0.000000\t2767872470                     1475
#
#                                                     Missing Values
# 1331901047.230000\tCCHNFI4C6RAO93bP7\t192.168.2...               0
# 26                                                               0
# 9e                                                               0
# 83                                                               0
# a2                                                               0
# 30\t192.168.202.76\t0.000000\t2767872470                         0

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("/content/data/output.csv")

# %%
df.head()
# Out:
#   1331901047.230000\tCCHNFI4C6RAO93bP7\t192.168.202.76\t68\t192.168.202.1\t67\t00  \
# 0  1331901117.740000\tCouYOF1J4EnQkQNSl3\t192.168...
# 1  1331901120.620000\tC9svD93TrEvPshF7Gf\t192.168...
# 2  1331901121.800000\tC2nAD54rXz5nILppHh\t192.168...
# 3  1331901182.540000\tCVRJN6491gIrhKWzHk\t192.168...
# 4  1331901216.820000\tCl244gl1V2Yyf4h1f\t192.168....
#
#    26  9e  83  a2  30\t192.168.202.76\t0.000000\t2767872470
# 0  26  b9  da  95  2c\t192.168.204.69\t0.000000\t2023309577
# 1  de  f1  2e  6a    5a\t192.168.202.102\t0.000000\t7111068
# 2  26  9e  83  a2  30\t192.168.202.76\t0.000000\t4022009768
# 3  26  b9  da  95  2c\t192.168.204.69\t0.000000\t3428947570
# 4  26  9e  83  a2  30\t192.168.202.76\t0.000000\t3106841135
